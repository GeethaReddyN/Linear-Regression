# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression #importing

# %%
x=np.arange(-500,500)/10+np.random.randn(1000)
y=(4*(x**2))+(3*x)

# %%
plt.plot(x,y)

# %%
df=pd.read_csv('advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sns.scatterplot(x='TV',y='Sales',data=df)
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Sales'>

# %%
sns.pairplot(df)

# %%
g=sns.FacetGrid(df,col='Sales')

# %%
fig,ax=plt.subplots(1,3,figsize=(18,6))
plt.style.use('seaborn')
ax[0].scatter(df.TV,df.Sales)
ax[1].scatter(df.Radio,df.Sales)
ax[2].scatter(df.Newspaper,df.Sales)

# %%
# g = sns.FacetGrid(df, col="Sales",  row="sex")
# g.map(sns.scatterplot, "total_bill", "tip")

# %%
X=df[['TV','Radio','Newspaper']]
y=df['Sales']

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# ### To create any machine learning model in sklearn we have to use 4 steps
# ### 1.import the model
# ### 2.Instantiate the model
# ### 3.fit the model
# ### 4.predict

# %%
model=LinearRegression() #instantiate
model.fit(X_train,y_train) #fit the model,this is where OLS is applied
# Out:
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.0529484  0.11019984 0.00046462]
# 4.790926512091525

# %%
model.predict(np.array([180,340,20]).reshape(1,3))
# Out:
# array([51.79887493])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_test.shape
# Out:
# (40, 3)

# %%
X_train.shape
# Out:
# (160, 3)

# %%
y_train.shape
# Out:
# (160,)

# %%
y_test.shape
# Out:
# (40,)

# %%
y_test.dtype
# Out:
# dtype('float64')

# %%
from sklearn.metrics import r2_score

# %%
y_pred=model.predict(X_test)

# %%
score=r2_score(y_test,y_pred)
score
# Out:
# 0.8567694789815106
